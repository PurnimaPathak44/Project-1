# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import requests
from api_keys import api_key
from scipy.stats import linregress

url = f"http://www.omdbapi.com/?apikey={api_key}&t="

# %%
# Read saved data
movie_data_df = pd.read_csv("../Resources/clean_movies_data_fixed.csv", index_col="imdb_id")
awards_df = pd.read_csv("../Resources/awarded_movies.csv")

# Display sample data
movie_data_df.head(3)
# Out:
#            Unnamed: 0  popularity     budget     revenue      original_title  \
# imdb_id
# tt0369610           0   32.985763  150000000  1513528810      Jurassic World
# tt1392190           1   28.419936  150000000   378436354  Mad Max: Fury Road
# tt2908446           2   13.112507  110000000   295238201           Insurgent
#
#                                                         cast  \
# imdb_id
# tt0369610   'Chris Pratt', 'Bryce Dallas Howard', 'Irrfan...
# tt1392190   'Tom Hardy', 'Charlize Theron', 'Hugh Keays-B...
# tt2908446   'Shailene Woodley', 'Theo James', 'Kate Winsl...
#
#                    director  \
# imdb_id
# tt0369610   Colin Trevorrow
# tt1392190     George Miller
# tt2908446  Robert Schwentke
#
#                                                     keywords  runtime  \
# imdb_id
# tt0369610   'monster', 'dna', 'tyrannosaurus rex', 'veloc...      124
# tt1392190   'future', 'chase', 'post-apocalyptic', 'dysto...      120
# tt2908446   'based on novel', 'revolution', 'dystopia', '...      119
#
#                                                       genres  \
# imdb_id
# tt0369610   'Action', 'Adventure', 'Science Fiction', 'Th...
# tt1392190   'Action', 'Adventure', 'Science Fiction', 'Th...
# tt2908446         'Adventure', 'Science Fiction', 'Thriller'
#
#                                         production_companies release_date  \
# imdb_id
# tt0369610   'Universal Studios', 'Amblin Entertainment', ...     6/9/2015
# tt1392190   'Village Roadshow Pictures', 'Kennedy Miller ...    5/13/2015
# tt2908446   'Summit Entertainment', 'Mandeville Films', '...    3/18/2015
#
#            vote_count  vote_average  release_year  budget_adj  revenue_adj  \
# imdb_id
# tt0369610        5562           6.5          2015   137999939   1392445892
# tt1392190        6185           7.1          2015   137999939    348161292
# tt2908446        2480           6.3          2015   101199955    271619025
#
#                profit popularity_level
# imdb_id
# tt0369610  1363528810             High
# tt1392190   228436354             High
# tt2908446   185238201             High
